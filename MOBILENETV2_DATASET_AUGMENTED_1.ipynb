# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import confusion_matrix, classification_report

import os
from tensorflow.keras.models import load_model

# from sklearn.metrics import roc_auc_score, roc_curve, auc
# from sklearn.preprocessing import label_binarize

# %%
train_dir = '/content/drive/MyDrive/dataset_kentang/dataset_augmented_1/train'
validation_dir = '/content/drive/MyDrive/dataset_kentang/dataset_augmented_1/validation'
test_dir = '/content/drive/MyDrive/dataset_kentang/dataset_augmented_1/test'

# %%
urutan_folder = ['blackspot_bruising', 'healthy_potato', 'brown_rot', 'dry_rot', 'soft_rot']

# %%
folder_paths = ['/content/drive/MyDrive/dataset_kentang/dataset_augmented_1/train/blackspot_bruising',
                '/content/drive/MyDrive/dataset_kentang/dataset_augmented_1/train/healthy_potato',
                '/content/drive/MyDrive/dataset_kentang/dataset_augmented_1/train/brown_rot',
                '/content/drive/MyDrive/dataset_kentang/dataset_augmented_1/train/dry_rot',
                '/content/drive/MyDrive/dataset_kentang/dataset_augmented_1/train/soft_rot']

# Inisialisasi list untuk menyimpan jumlah gambar di setiap folder
jumlah_gambar = []

# Loop melalui setiap folder
for folder_path in folder_paths:
    # Hitung jumlah file gambar dalam folder
    jumlah_file = len([file for file in os.listdir(folder_path) if file.endswith(('.jpg'))])

    # Tambahkan jumlah file ke list
    jumlah_gambar.append(jumlah_file)

# Buat diagram batang
plt.bar(urutan_folder, jumlah_gambar)
plt.xlabel('Kelas')
plt.ylabel('Jumlah Gambar')
plt.title('Perbedaan Jumlah Gambar pada Folder Train')
plt.show()

# %%
folder_paths = ['/content/drive/MyDrive/dataset_kentang/dataset_augmented_1/validation/blackspot_bruising',
                '/content/drive/MyDrive/dataset_kentang/dataset_augmented_1/validation/healthy_potato',
                '/content/drive/MyDrive/dataset_kentang/dataset_augmented_1/validation/brown_rot',
                '/content/drive/MyDrive/dataset_kentang/dataset_augmented_1/validation/dry_rot',
                '/content/drive/MyDrive/dataset_kentang/dataset_augmented_1/validation/soft_rot']

# Inisialisasi list untuk menyimpan jumlah gambar di setiap folder
jumlah_gambar = []

# Loop melalui setiap folder
for folder_path in folder_paths:
    # Hitung jumlah file gambar dalam folder
    jumlah_file = len([file for file in os.listdir(folder_path) if file.endswith(('.jpg'))])

    # Tambahkan jumlah file ke list
    jumlah_gambar.append(jumlah_file)

# Buat diagram batang
plt.bar(urutan_folder, jumlah_gambar)
plt.xlabel('Kelas')
plt.ylabel('Jumlah Gambar')
plt.title('Perbedaan Jumlah Gambar pada Folder Validation')
plt.show()

# %%
folder_paths = ['/content/drive/MyDrive/dataset_kentang/dataset_augmented_1/test/blackspot_bruising',
                '/content/drive/MyDrive/dataset_kentang/dataset_augmented_1/test/healthy_potato',
                '/content/drive/MyDrive/dataset_kentang/dataset_augmented_1/test/brown_rot',
                '/content/drive/MyDrive/dataset_kentang/dataset_augmented_1/test/dry_rot',
                '/content/drive/MyDrive/dataset_kentang/dataset_augmented_1/test/soft_rot']

# Inisialisasi list untuk menyimpan jumlah gambar di setiap folder
jumlah_gambar = []

# Loop melalui setiap folder
for folder_path in folder_paths:
    # Hitung jumlah file gambar dalam folder
    jumlah_file = len([file for file in os.listdir(folder_path) if file.endswith(('.jpg'))])

    # Tambahkan jumlah file ke list
    jumlah_gambar.append(jumlah_file)

# Buat diagram batang
plt.bar(urutan_folder, jumlah_gambar)
plt.xlabel('Kelas')
plt.ylabel('Jumlah Gambar')
plt.title('Perbedaan Jumlah Gambar pada Folder Test')
plt.show()

# %%
preprocessing_dataset = ImageDataGenerator(rescale=1./255)

# %%
train_generator = preprocessing_dataset.flow_from_directory(
    train_dir,
    target_size=(224, 224),
    batch_size=64,
    class_mode='categorical'
)
# Out:
# Found 2425 images belonging to 5 classes.

# %%
validation_generator = preprocessing_dataset.flow_from_directory(
    validation_dir,
    target_size=(224, 224),
    batch_size=64,
    class_mode='categorical'
)
# Out:
# Found 690 images belonging to 5 classes.

# %%
test_generator = preprocessing_dataset.flow_from_directory(
    test_dir,
    target_size=(224, 224),
    batch_size=64,
    class_mode='categorical',
    shuffle=False
)
# Out:
# Found 350 images belonging to 5 classes.

# %%
base_model = MobileNetV2(
    weights='imagenet',
    include_top=False,
    pooling=max,
    input_shape=(224, 224, 3)
    )

for layer in base_model.layers:
    layer.trainable = False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 [==============================] - 0s 0us/step

# %%
model = Sequential()
model.add(base_model)
model.add(Flatten())
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(5, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  mobilenetv2_1.00_224 (Func  (None, 7, 7, 1280)        2257984
#  tional)
#
#  flatten (Flatten)           (None, 62720)             0
#
#  dense (Dense)               (None, 1024)              64226304
#
#  dropout (Dropout)           (None, 1024)              0
#
#  dense_1 (Dense)             (None, 5)                 5125
#
# =================================================================
# Total params: 66489413 (253.64 MB)
# Trainable params: 64231429 (245.02 MB)
# Non-trainable params: 2257984 (8.61 MB)
# _________________________________________________________________

# %%
model.compile(
    optimizer=Adam(),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
history = model.fit(
    train_generator,
    epochs=10,
    validation_data=validation_generator
)
# Out:
# Epoch 1/10
# 38/38 [==============================] - 1052s 28s/step - loss: 14.1779 - accuracy: 0.6944 - val_loss: 1.1843 - val_accuracy: 0.8942
# Epoch 2/10
# 38/38 [==============================] - 19s 497ms/step - loss: 0.5699 - accuracy: 0.9188 - val_loss: 0.4293 - val_accuracy: 0.9217
# Epoch 3/10
# 38/38 [==============================] - 20s 516ms/step - loss: 0.1461 - accuracy: 0.9649 - val_loss: 0.2407 - val_accuracy: 0.9391
# Epoch 4/10
# 38/38 [==============================] - 18s 484ms/step - loss: 0.0782 - accuracy: 0.9806 - val_loss: 0.2194 - val_accuracy: 0.9406
# Epoch 5/10
# 38/38 [==============================] - 18s 487ms/step - loss: 0.0481 - accuracy: 0.9847 - val_loss: 0.1925 - val_accuracy: 0.9507
# Epoch 6/10
# 38/38 [==============================] - 19s 494ms/step - loss: 0.0412 - accuracy: 0.9876 - val_loss: 0.1948 - val_accuracy: 0.9551
# Epoch 7/10
# 38/38 [==============================] - 18s 483ms/step - loss: 0.0425 - accuracy: 0.9872 - val_loss: 0.1769 - val_accuracy: 0.9565
# Epoch 8/10
# 38/38 [==============================] - 19s 494ms/step - loss: 0.0174 - accuracy: 0.9938 - val_loss: 0.1890 - val_accuracy: 0.9565
# Epoch 9/10
# 38/38 [==============================] - 20s 525ms/step - loss: 0.0315 - accuracy: 0.9893 - val_loss: 0.1638 - val_accuracy: 0.9638
# Epoch 10/10
# 38/38 [==============================] - 19s 498ms/step - loss: 0.0276 - accuracy: 0.9913 - val_loss: 0.1335 - val_accuracy: 0.9638

# %%
plt.subplot(1, 1, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss')
plt.xlabel('Epoch')
plt.legend()

# %%
plt.subplot(1, 1, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy')
plt.xlabel('Epoch')
plt.legend()

# %%
save_directory = '/content/drive/MyDrive/dataset_kentang/model_mobilenetv2/'
model.save(save_directory + 'mobilenetv2_dataset_augmented_1.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
new_model = load_model('/content/drive/MyDrive/dataset_kentang/model_mobilenetv2/mobilenetv2_dataset_augmented_1.h5')
new_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  mobilenetv2_1.00_224 (Func  (None, 7, 7, 1280)        2257984
#  tional)
#
#  flatten (Flatten)           (None, 62720)             0
#
#  dense (Dense)               (None, 1024)              64226304
#
#  dropout (Dropout)           (None, 1024)              0
#
#  dense_1 (Dense)             (None, 5)                 5125
#
# =================================================================
# Total params: 66489413 (253.64 MB)
# Trainable params: 64231429 (245.02 MB)
# Non-trainable params: 2257984 (8.61 MB)
# _________________________________________________________________

# %%
predictions = model.predict(test_generator)
predicted_classes = np.argmax(predictions, axis=1)
true_labels = test_generator.classes
urutan_folder = ['blackspot_bruising', 'healthy_potato', 'brown_rot', 'dry_rot', 'soft_rot']
# Out:
# 6/6 [==============================] - 118s 23s/step

# %%
class_report = classification_report(true_labels, predicted_classes, target_names=urutan_folder)
print("Classification Report:\n", class_report)
# Out:
# Classification Report:
#                      precision    recall  f1-score   support
#
# blackspot_bruising       0.96      0.96      0.96        70
#     healthy_potato       0.97      1.00      0.99        70
#          brown_rot       0.99      0.96      0.97        70
#            dry_rot       1.00      1.00      1.00        70
#           soft_rot       0.97      0.97      0.97        70
#
#           accuracy                           0.98       350
#          macro avg       0.98      0.98      0.98       350
#       weighted avg       0.98      0.98      0.98       350
